# %%
require(IPSUR)
require(HH)

# %%
temp <- prop.test(1755, 1755 + 2771, p = 0.4, alternative = "less", conf.level = 0.99, correct = FALSE)
temp
plot(temp, "Hypoth")
# Out:
# 	1-sample proportions test without continuity correction
#
# data:  1755 out of 1755 + 2771, null probability 0.4
# X-squared = 2.8255, df = 1, p-value = 0.04639
# alternative hypothesis: true p is less than 0.4
# 99 percent confidence interval:
#  0.0000000 0.4047326
# sample estimates:
#         p
# 0.3877596
# Warning message:
# In arrows(xbar2, par()$usr[3:4] + c(-0.01, 0.01), xbar2, par()$usr[3:4], : zero-length arrow is of indeterminate angle and so skippedWarning message:
# In arrows(xbar2, par()$usr[3:4] + c(-0.01, 0.01), xbar2, par()$usr[3:4], : zero-length arrow is of indeterminate angle and so skipped
